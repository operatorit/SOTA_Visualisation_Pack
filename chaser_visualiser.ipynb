# %% [markdown]
# # SOTA Chaser Visualiser
# by www.operator-paramedyk.pl / SQ9NIL
#
# explained step-by-step

# %% [markdown]
# ## What SOTA is?
#
# SOTA (Summits On The Air) is an activity designed for radio amateurs (called also HAMs) who like hiking. It is about communication via ration between an activator - operator who climbed a designated summit (map available at https://sotl.as/map) - and chasers - all other operators. Call  (or QSO) may be done with the use of telegraphy (morse code), voice or data transmission on any band available for radio amateurs. To make a successfull call, both operators need to exchange report, which say how they hear each other, and log it into a log. SOTA results are then uploaded into https://www.sotadata.org.uk/en/ webpage.
#
# You can find all information about SOTA programme at https://www.sota.org.uk/.
#
# This script is designed to visualise on a map all summits chased by an operator. It uses input from log saved in ADIF file (Amateur Data Interchange Format, see specification at https://www.adif.org/303/adif303.htm), gets coordinates of summits chased via SOTA API and plot results on a map.

# %% [markdown]
# ## Script alghorithm

# %% [markdown]
# ### Import of relevant packages
#
# There are seven packages to be installed for this script, all specified in requirements.txt file. You can install all of them at once typing in terminal following line:
#
# ```pip install -r requirements.txt```

# %% [markdown]
# If you use Google Colab (https://colab.research.google.com/) to run this script, uncomment and run the line below to install all packages that are not default in this environment.

# %%
# !pip install adif_io
# !pip install unidecode
# !pip install maidenhead

# %%
import adif_io as adif # to read the log
import pandas as pd # to analyse log as a DataFrame
import requests # to get data from SOTA API
from unidecode import unidecode # for log clearing
import folium # for data visualisation on a map
import maidenhead as mh # to calculate coordinates from GRID square
import branca.colormap as cm # to add colormap to the visualisation

# %% [markdown]
# ### Log upload and conversion
#
# You need to save your log as ADIF file. Then copy it into folder where SOTA Visualiser script is saved. As default, script will read SOTAlog.adi file, but you can change this by changing ```filename``` variable value.
#
# There's example log provied with within the repository, which is based on some of my chases for demonstration purposes.

# %%
# save name of your log under filename variable
filename = 'SOTAlog.adi'

# working_log will be used to save cleared log
working_log = 'working_log.adi'

# %% [markdown]
# Before importing the log, you need to clean it up to avoid errors due to the accents. Therefore, at the beginning, script will ll open the log file and pass it through `unidecode` function to change every local chart to the closest latin one. Then log will be saved under ```working_log.adi``` file.

# %%
with open(filename, 'r', encoding='ansi') as filelog:
    content = unidecode(filelog.read())
filelog.close()
with open(working_log, 'w') as filelog:
    filelog.write(content)
filelog.close()

# %% [markdown]
# Now, with the use of adif_id package, your log will be read and divided into two dictionaries:
# - ```log_header``` includes ADIF header and it's not used for visualisation, but has to be separated from the QSOs.
# - ```log_raw``` includes all your QSOs.

# %%
# load log into the variable log_raw, log_header stores header of ADIF file
log_raw,log_header = adif.read_from_file('working_log.adi')

# %% [markdown]
# Let's see how both dictionaries look like (for clarity, I present only 1st QSO, remaining ones follows the same structure):

# %%
log_header
# Out:
# {'ADIF_VER': '3.1.0', 'PROGRAMID': 'ADIFMaster', 'PROGRAMVERSION': '3.2'}

# %%
log_raw[0]
# Out:
# {'STATION_CALLSIGN': 'SQ9NIL',
#  'MY_GRIDSQUARE': 'KO00AA',
#  'CALL': 'SQ9JTR/P',
#  'GRIDSQUARE': 'KN19GC',
#  'QTH': 'Wielka Rawka',
#  'SOTA_REF': 'SP/BI-003',
#  'RST_RCVD': '31',
#  'RST_SENT': '53',
#  'FREQ': '145.550',
#  'BAND': '2M',
#  'MODE': 'FM',
#  'COMMENT': '145.550',
#  'QSO_DATE': '20211106',
#  'TIME_ON': '083500',
#  'QSO_DATE_OFF': '20211106',
#  'TIME_OFF': '083600'}

# %% [markdown]
# To make log processing and analysis easier, let's save it as Pandas DataFrame object. First we need to check if there are any chases to visualise - if no, script will cease operation. IF there are SOTA references logged, all of them will be converted to unified format (upper letters only) to avoid duplicate work in coming steps.

# %%
# convert the log into DataFrame df_log_raw
df_log_raw = pd.DataFrame(log_raw)

if df_log_raw['SOTA_REF'].count() == 0:
    print('No SOTA chases found in log.')
    exit()
else:
    df_log_raw['SOTA_REF'] = df_log_raw['SOTA_REF'].str.upper()

# %% [markdown]
# Now your QSOs are saved in following table (first rows are displayed):

# %%
df_log_raw.head()
# Out:
#   STATION_CALLSIGN MY_GRIDSQUARE      CALL GRIDSQUARE           QTH  \
# 0           SQ9NIL        KO00AA  SQ9JTR/P     KN19GC  Wielka Rawka
# 1           SQ9NIL        KO00AA  SP9OZI/P        NaN           NaN
# 2           SQ9NIL        KO00AA  SP9OZI/P        NaN           NaN
# 3           SQ9NIL        KO00AA  SQ9JTR/P        NaN           NaN
# 4         SQ9NIL/P        KN09GR    SP9MOV        NaN           NaN
#
#     SOTA_REF RST_RCVD RST_SENT     FREQ BAND MODE  COMMENT  QSO_DATE TIME_ON  \
# 0  SP/BI-003       31       53  145.550   2M   FM  145.550  20211106  083500
# 1  SP/BZ-070       59       59  145.550   2M   FM  145.550  20211106  123400
# 2  SP/BZ-082       57       59  145.550   2M   FM  145.550  20211106  150300
# 3  SP/BZ-001       43       59  145.550   2M   FM  145.550  20211111  094100
# 4        NaN       59       59  145.500   2M   FM  145.500  20211111  111800
#
#   QSO_DATE_OFF TIME_OFF MY_SOTA_REF NAME OPERATOR TX_PWR
# 0     20211106   083600         NaN  NaN      NaN    NaN
# 1     20211106   123500         NaN  NaN      NaN    NaN
# 2     20211106   150400         NaN  NaN      NaN    NaN
# 3     20211111   094100         NaN  NaN      NaN    NaN
# 4     20211111   111700   SP/BZ-049  NaN      NaN    NaN

# %% [markdown]
# ### Prepare data for visualisation
#
# Let's check what is the structure of data in log:

# %%
df_log_raw.count()
# Out:
# STATION_CALLSIGN    48
# MY_GRIDSQUARE       48
# CALL                48
# GRIDSQUARE           1
# QTH                  3
# SOTA_REF            32
# RST_RCVD            48
# RST_SENT            48
# FREQ                48
# BAND                48
# MODE                48
# COMMENT             22
# QSO_DATE            48
# TIME_ON             48
# QSO_DATE_OFF        22
# TIME_OFF            48
# MY_SOTA_REF         17
# NAME                16
# OPERATOR            26
# TX_PWR              26
# dtype: int64

# %% [markdown]
# In row count you can see that (in my example) 48 QSOs are saved, but SOTA reference (SOTA_REF row) are provide only for 32 of them. It means that some QSO was not related to SOTA chase. Let's clear the log and remove all records where no SOTA summit reference is provided.
#
# You can check which records include SOTA reference - ```True``` value is returned for them:

# %%
df_log_raw.SOTA_REF.notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22    False
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# Name: SOTA_REF, dtype: bool

# %% [markdown]
# Now let's remove the rows where SOTA_REF column is empty and name the new DataFrame as df_log_SOTA:

# %%
# data filtering - move to further analysis only entries with SOTA reference provided in SOTA_REF column
df_log_SOTA = df_log_raw[df_log_raw.SOTA_REF.notnull()]

# %% [markdown]
# New DataFrame includes all columns we had in our log:

# %%
df_log_SOTA.head()
# Out:
#   STATION_CALLSIGN MY_GRIDSQUARE      CALL GRIDSQUARE           QTH  \
# 0           SQ9NIL        KO00AA  SQ9JTR/P     KN19GC  Wielka Rawka
# 1           SQ9NIL        KO00AA  SP9OZI/P        NaN           NaN
# 2           SQ9NIL        KO00AA  SP9OZI/P        NaN           NaN
# 3           SQ9NIL        KO00AA  SQ9JTR/P        NaN           NaN
# 7         SQ9NIL/P        KN09GR  SQ9PPW/P        NaN           NaN
#
#     SOTA_REF RST_RCVD RST_SENT     FREQ BAND MODE       COMMENT  QSO_DATE  \
# 0  SP/BI-003       31       53  145.550   2M   FM       145.550  20211106
# 1  SP/BZ-070       59       59  145.550   2M   FM       145.550  20211106
# 2  SP/BZ-082       57       59  145.550   2M   FM       145.550  20211106
# 3  SP/BZ-001       43       59  145.550   2M   FM       145.550  20211111
# 7  SP/BZ-059       59       59  145.500   2M   FM  145.500, S2S  20211111
#
#   TIME_ON QSO_DATE_OFF TIME_OFF MY_SOTA_REF NAME OPERATOR TX_PWR
# 0  083500     20211106   083600         NaN  NaN      NaN    NaN
# 1  123400     20211106   123500         NaN  NaN      NaN    NaN
# 2  150300     20211106   150400         NaN  NaN      NaN    NaN
# 3  094100     20211111   094100         NaN  NaN      NaN    NaN
# 7  112400     20211111   112500   SP/BZ-049  NaN      NaN    NaN

# %% [markdown]
# But all records now have SOTA summit reference included:

# %%
df_log_SOTA.count()
# Out:
# STATION_CALLSIGN    32
# MY_GRIDSQUARE       32
# CALL                32
# GRIDSQUARE           1
# QTH                  1
# SOTA_REF            32
# RST_RCVD            32
# RST_SENT            32
# FREQ                32
# BAND                32
# MODE                32
# COMMENT              8
# QSO_DATE            32
# TIME_ON             32
# QSO_DATE_OFF         8
# TIME_OFF            32
# MY_SOTA_REF          3
# NAME                12
# OPERATOR            24
# TX_PWR              24
# dtype: int64

# %% [markdown]
# ### Get SOTA summits data from SOTA API
#
# Now, we will use SOTA API (https://api2.sota.org.uk/docs/index.html) to get data of summits chased.
#
# We'll check which specific summits are present in the log uploaded. To do this, we create a new Series containing data from SOTA_REF column of the log with duplicates removed.

# %%
df_log_summits = df_log_SOTA['SOTA_REF'].copy().drop_duplicates().reset_index()
del(df_log_summits['index'])
df_log_summits
# Out:
#      SOTA_REF
# 0   SP/BI-003
# 1   SP/BZ-070
# 2   SP/BZ-082
# 3   SP/BZ-001
# 4   SP/BZ-059
# 5   SP/WS-003
# 6   OM/PO-040
# 7   SP/BZ-010
# 8   SP/BZ-030
# 9   SP/BZ-024
# 10  SP/BZ-031
# 11  SP/BZ-005
# 12  SP/BZ-014

# %% [markdown]
# With the list of summits in scope, we can go to the SOTA API and download data for every summit chased into ```summits_dict``` dictionary. If there are any exceptions (e.g. due to the incorrectly logged summit reference), summit reference with error code will be saved in ```errors_dict``` dictionary and displayed to notify user about the errors found.

# %%
summits_dict={}
errors_dict = {}
url = 'https://api2.sota.org.uk/api/summits/'

for summit in df_log_summits['SOTA_REF']:
    summit_url = f"{url}{summit}"
    try:
        r = requests.get(summit_url)
        print(f'Status code: {r.status_code} for {summit}')
        summits_dict[summit] = r.json()
    except Exception:
        errors_dict[summit] = r.status_code
        pass

if errors_dict:
    print(f'\nFollowing errors were reported - QSO will be not included')
    for summit in errors_dict.keys():
        print(f'Error {errors_dict[summit]} for {summit}.')
        df_log_summits = df_log_summits.loc[df_log_summits['SOTA_REF'] != summit]
# Out:
# Status code: 200 for SP/BI-003
# Status code: 200 for SP/BZ-070
# Status code: 200 for SP/BZ-082
# Status code: 200 for SP/BZ-001
# Status code: 200 for SP/BZ-059
# Status code: 200 for SP/WS-003
# Status code: 200 for OM/PO-040
# Status code: 200 for SP/BZ-010
# Status code: 200 for SP/BZ-030
# Status code: 200 for SP/BZ-024
# Status code: 200 for SP/BZ-031
# Status code: 200 for SP/BZ-005
# Status code: 200 for SP/BZ-014

# %% [markdown]
# Similarly to the log, let's save the summits data downloaded as DataFrame object.

# %%
df_summits = pd.DataFrame(summits_dict)
df_summits
# Out:
#                            SP/BI-003            SP/BZ-070  \
# summitCode                 SP/BI-003            SP/BZ-070
# name                    Wielka Rawka              Kostrza
# shortCode                     BI-003               BZ-070
# altM                            1307                  730
# altFt                           4288                 2395
# gridRef1                     22.5780              20.2993
# gridRef2                     49.0988              49.7708
# notes
# validFrom        0001-01-01T00:00:00  0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00  0001-01-01T00:00:00
# activationCount                 None                 None
# myActivations                   None                 None
# activationDate                  None                 None
# myChases                        None                 None
# activationCall                  None                 None
# longitude                     22.578              20.2993
# latitude                     49.0988              49.7708
# locator                       KN19gc               KN09ds
# points                            10                    4
# regionCode                        BI                   BZ
# regionName                Bieszczady    Beskidy Zachodnie
# associationCode                   SP                   SP
# associationName               Poland               Poland
# valid                           True                 True
# restrictionMask                False                False
# restrictionList                   []                   []
#
#                            SP/BZ-082             SP/BZ-001  \
# summitCode                 SP/BZ-082             SP/BZ-001
# name                           Zęzów  Diablak (Babia Góra)
# shortCode                     BZ-082                BZ-001
# altM                             693                  1725
# altFt                           2273                  5659
# gridRef1                     20.3198               19.5296
# gridRef2                     49.7467               49.5732
# notes
# validFrom        0001-01-01T00:00:00   0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00   0001-01-01T00:00:00
# activationCount                 None                  None
# myActivations                   None                  None
# activationDate                  None                  None
# myChases                        None                  None
# activationCall                  None                  None
# longitude                    20.3198               19.5296
# latitude                     49.7467               49.5732
# locator                       KN09dr                JN99sn
# points                             2                    10
# regionCode                        BZ                    BZ
# regionName         Beskidy Zachodnie     Beskidy Zachodnie
# associationCode                   SP                    SP
# associationName               Poland                Poland
# valid                           True                  True
# restrictionMask                False                 False
# restrictionList                   []                    []
#
#                            SP/BZ-059                        SP/WS-003  \
# summitCode                 SP/BZ-059                        SP/WS-003
# name                           Kotoń  Góra Zamkowa (Góra Janowskiego)
# shortCode                     BZ-059                           WS-003
# altM                             857                              516
# altFt                           2812                             1691
# gridRef1                     19.8961                          19.5536
# gridRef2                     49.7689                          50.4511
# notes
# validFrom        0001-01-01T00:00:00              0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00              0001-01-01T00:00:00
# activationCount                 None                             None
# myActivations                   None                             None
# activationDate                  None                             None
# myChases                        None                             None
# activationCall                  None                             None
# longitude                    19.8961                          19.5536
# latitude                     49.7689                          50.4511
# locator                       JN99ws                           JO90sk
# points                             6                                1
# regionCode                        BZ                               WS
# regionName         Beskidy Zachodnie                    Wyzyna Slaska
# associationCode                   SP                               SP
# associationName               Poland                           Poland
# valid                           True                             True
# restrictionMask                False                            False
# restrictionList                   []                               []
#
#                            OM/PO-040                SP/BZ-010  \
# summitCode                 OM/PO-040                SP/BZ-010
# name                        Javorina  Gorc (Gorc Kamieniecki)
# shortCode                     PO-040                   BZ-010
# altM                             881                     1228
# altFt                           2890                     4029
# gridRef1                     21.2637                  20.2528
# gridRef2                     49.4473                  49.5653
# notes
# validFrom        0001-01-01T00:00:00      0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00      0001-01-01T00:00:00
# activationCount                 None                     None
# myActivations                   None                     None
# activationDate                  None                     None
# myChases                        None                     None
# activationCall                  None                     None
# longitude                    21.2637                  20.2528
# latitude                     49.4473                  49.5653
# locator                       KN09pk                   KN09dn
# points                             2                        8
# regionCode                        PO                       BZ
# regionName                 Prešovský        Beskidy Zachodnie
# associationCode                   OM                       SP
# associationName             Slovakia                   Poland
# valid                           True                     True
# restrictionMask                False                    False
# restrictionList                   []                       []
#
#                            SP/BZ-030            SP/BZ-024  \
# summitCode                 SP/BZ-030            SP/BZ-024
# name                           Modyń               Ćwilin
# shortCode                     BZ-030               BZ-024
# altM                            1028                 1072
# altFt                           3373                 3517
# gridRef1                      20.376              20.1916
# gridRef2                     49.6212              49.6887
# notes
# validFrom        0001-01-01T00:00:00  0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00  0001-01-01T00:00:00
# activationCount                 None                 None
# myActivations                   None                 None
# activationDate                  None                 None
# myChases                        None                 None
# activationCall                  None                 None
# longitude                     20.376              20.1916
# latitude                     49.6212              49.6887
# locator                       KN09eo               KN09cq
# points                             8                    8
# regionCode                        BZ                   BZ
# regionName         Beskidy Zachodnie    Beskidy Zachodnie
# associationCode                   SP                   SP
# associationName               Poland               Poland
# valid                           True                 True
# restrictionMask                False                False
# restrictionList                   []                   []
#
#                             SP/BZ-031            SP/BZ-005  \
# summitCode                  SP/BZ-031            SP/BZ-005
# name             Luboń (Luboń Wielki)              Turbacz
# shortCode                      BZ-031               BZ-005
# altM                             1022                 1315
# altFt                            3353                 4314
# gridRef1                      19.9919              20.1113
# gridRef2                      49.6535              49.5429
# notes
# validFrom         0001-01-01T00:00:00  0001-01-01T00:00:00
# validTo           0001-01-01T00:00:00  0001-01-01T00:00:00
# activationCount                  None                 None
# myActivations                    None                 None
# activationDate                   None                 None
# myChases                         None                 None
# activationCall                   None                 None
# longitude                     19.9919              20.1113
# latitude                      49.6535              49.5429
# locator                        JN99xp               KN09bn
# points                              8                   10
# regionCode                         BZ                   BZ
# regionName          Beskidy Zachodnie    Beskidy Zachodnie
# associationCode                    SP                   SP
# associationName                Poland               Poland
# valid                            True                 True
# restrictionMask                 False                False
# restrictionList                    []                   []
#
#                            SP/BZ-014
# summitCode                 SP/BZ-014
# name                       Mogielica
# shortCode                     BZ-014
# altM                            1171
# altFt                           3842
# gridRef1                     20.2768
# gridRef2                     49.6552
# notes
# validFrom        0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00
# activationCount                 None
# myActivations                   None
# activationDate                  None
# myChases                        None
# activationCall                  None
# longitude                    20.2768
# latitude                     49.6552
# locator                       KN09dp
# points                             8
# regionCode                        BZ
# regionName         Beskidy Zachodnie
# associationCode                   SP
# associationName               Poland
# valid                           True
# restrictionMask                False
# restrictionList                   []

# %% [markdown]
# As you can see, dataframe `df_summits` includes field `myChases`, currently filled with `None` values. We can use this field to save number of chases for each summit.

# %%
for summit in df_log_summits['SOTA_REF']:
    df_summits[summit]['myChases'] = df_log_SOTA[['SOTA_REF']][df_log_SOTA['SOTA_REF'] == summit].count()[0]

# %%
df_summits.keys
# Out:
# <bound method NDFrame.keys of                            SP/BI-003            SP/BZ-070  \
# summitCode                 SP/BI-003            SP/BZ-070
# name                    Wielka Rawka              Kostrza
# shortCode                     BI-003               BZ-070
# altM                            1307                  730
# altFt                           4288                 2395
# gridRef1                     22.5780              20.2993
# gridRef2                     49.0988              49.7708
# notes
# validFrom        0001-01-01T00:00:00  0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00  0001-01-01T00:00:00
# activationCount                 None                 None
# myActivations                   None                 None
# activationDate                  None                 None
# myChases                           1                    1
# activationCall                  None                 None
# longitude                     22.578              20.2993
# latitude                     49.0988              49.7708
# locator                       KN19gc               KN09ds
# points                            10                    4
# regionCode                        BI                   BZ
# regionName                Bieszczady    Beskidy Zachodnie
# associationCode                   SP                   SP
# associationName               Poland               Poland
# valid                           True                 True
# restrictionMask                False                False
# restrictionList                   []                   []
#
#                            SP/BZ-082             SP/BZ-001  \
# summitCode                 SP/BZ-082             SP/BZ-001
# name                           Zęzów  Diablak (Babia Góra)
# shortCode                     BZ-082                BZ-001
# altM                             693                  1725
# altFt                           2273                  5659
# gridRef1                     20.3198               19.5296
# gridRef2                     49.7467               49.5732
# notes
# validFrom        0001-01-01T00:00:00   0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00   0001-01-01T00:00:00
# activationCount                 None                  None
# myActivations                   None                  None
# activationDate                  None                  None
# myChases                           1                     1
# activationCall                  None                  None
# longitude                    20.3198               19.5296
# latitude                     49.7467               49.5732
# locator                       KN09dr                JN99sn
# points                             2                    10
# regionCode                        BZ                    BZ
# regionName         Beskidy Zachodnie     Beskidy Zachodnie
# associationCode                   SP                    SP
# associationName               Poland                Poland
# valid                           True                  True
# restrictionMask                False                 False
# restrictionList                   []                    []
#
#                            SP/BZ-059                        SP/WS-003  \
# summitCode                 SP/BZ-059                        SP/WS-003
# name                           Kotoń  Góra Zamkowa (Góra Janowskiego)
# shortCode                     BZ-059                           WS-003
# altM                             857                              516
# altFt                           2812                             1691
# gridRef1                     19.8961                          19.5536
# gridRef2                     49.7689                          50.4511
# notes
# validFrom        0001-01-01T00:00:00              0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00              0001-01-01T00:00:00
# activationCount                 None                             None
# myActivations                   None                             None
# activationDate                  None                             None
# myChases                           1                                1
# activationCall                  None                             None
# longitude                    19.8961                          19.5536
# latitude                     49.7689                          50.4511
# locator                       JN99ws                           JO90sk
# points                             6                                1
# regionCode                        BZ                               WS
# regionName         Beskidy Zachodnie                    Wyzyna Slaska
# associationCode                   SP                               SP
# associationName               Poland                           Poland
# valid                           True                             True
# restrictionMask                False                            False
# restrictionList                   []                               []
#
#                            OM/PO-040                SP/BZ-010  \
# summitCode                 OM/PO-040                SP/BZ-010
# name                        Javorina  Gorc (Gorc Kamieniecki)
# shortCode                     PO-040                   BZ-010
# altM                             881                     1228
# altFt                           2890                     4029
# gridRef1                     21.2637                  20.2528
# gridRef2                     49.4473                  49.5653
# notes
# validFrom        0001-01-01T00:00:00      0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00      0001-01-01T00:00:00
# activationCount                 None                     None
# myActivations                   None                     None
# activationDate                  None                     None
# myChases                           1                        1
# activationCall                  None                     None
# longitude                    21.2637                  20.2528
# latitude                     49.4473                  49.5653
# locator                       KN09pk                   KN09dn
# points                             2                        8
# regionCode                        PO                       BZ
# regionName                 Prešovský        Beskidy Zachodnie
# associationCode                   OM                       SP
# associationName             Slovakia                   Poland
# valid                           True                     True
# restrictionMask                False                    False
# restrictionList                   []                       []
#
#                            SP/BZ-030            SP/BZ-024  \
# summitCode                 SP/BZ-030            SP/BZ-024
# name                           Modyń               Ćwilin
# shortCode                     BZ-030               BZ-024
# altM                            1028                 1072
# altFt                           3373                 3517
# gridRef1                      20.376              20.1916
# gridRef2                     49.6212              49.6887
# notes
# validFrom        0001-01-01T00:00:00  0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00  0001-01-01T00:00:00
# activationCount                 None                 None
# myActivations                   None                 None
# activationDate                  None                 None
# myChases                          16                    2
# activationCall                  None                 None
# longitude                     20.376              20.1916
# latitude                     49.6212              49.6887
# locator                       KN09eo               KN09cq
# points                             8                    8
# regionCode                        BZ                   BZ
# regionName         Beskidy Zachodnie    Beskidy Zachodnie
# associationCode                   SP                   SP
# associationName               Poland               Poland
# valid                           True                 True
# restrictionMask                False                False
# restrictionList                   []                   []
#
#                             SP/BZ-031            SP/BZ-005  \
# summitCode                  SP/BZ-031            SP/BZ-005
# name             Luboń (Luboń Wielki)              Turbacz
# shortCode                      BZ-031               BZ-005
# altM                             1022                 1315
# altFt                            3353                 4314
# gridRef1                      19.9919              20.1113
# gridRef2                      49.6535              49.5429
# notes
# validFrom         0001-01-01T00:00:00  0001-01-01T00:00:00
# validTo           0001-01-01T00:00:00  0001-01-01T00:00:00
# activationCount                  None                 None
# myActivations                    None                 None
# activationDate                   None                 None
# myChases                            2                    2
# activationCall                   None                 None
# longitude                     19.9919              20.1113
# latitude                      49.6535              49.5429
# locator                        JN99xp               KN09bn
# points                              8                   10
# regionCode                         BZ                   BZ
# regionName          Beskidy Zachodnie    Beskidy Zachodnie
# associationCode                    SP                   SP
# associationName                Poland               Poland
# valid                            True                 True
# restrictionMask                 False                False
# restrictionList                    []                   []
#
#                            SP/BZ-014
# summitCode                 SP/BZ-014
# name                       Mogielica
# shortCode                     BZ-014
# altM                            1171
# altFt                           3842
# gridRef1                     20.2768
# gridRef2                     49.6552
# notes
# validFrom        0001-01-01T00:00:00
# validTo          0001-01-01T00:00:00
# activationCount                 None
# myActivations                   None
# activationDate                  None
# myChases                           2
# activationCall                  None
# longitude                    20.2768
# latitude                     49.6552
# locator                       KN09dp
# points                             8
# regionCode                        BZ
# regionName         Beskidy Zachodnie
# associationCode                   SP
# associationName               Poland
# valid                           True
# restrictionMask                False
# restrictionList                   []  >

# %% [markdown]
# Before visualisation, we'll do one more step to make - transpond the ```df_summits```  DataFrame so each column (Series object) consist of the same type of data.

# %%
df_summits_transposed = df_summits.transpose(copy = True)
df_summits_transposed
# Out:
#           summitCode                             name shortCode  altM altFt  \
# SP/BI-003  SP/BI-003                     Wielka Rawka    BI-003  1307  4288
# SP/BZ-070  SP/BZ-070                          Kostrza    BZ-070   730  2395
# SP/BZ-082  SP/BZ-082                            Zęzów    BZ-082   693  2273
# SP/BZ-001  SP/BZ-001             Diablak (Babia Góra)    BZ-001  1725  5659
# SP/BZ-059  SP/BZ-059                            Kotoń    BZ-059   857  2812
# SP/WS-003  SP/WS-003  Góra Zamkowa (Góra Janowskiego)    WS-003   516  1691
# OM/PO-040  OM/PO-040                         Javorina    PO-040   881  2890
# SP/BZ-010  SP/BZ-010          Gorc (Gorc Kamieniecki)    BZ-010  1228  4029
# SP/BZ-030  SP/BZ-030                            Modyń    BZ-030  1028  3373
# SP/BZ-024  SP/BZ-024                           Ćwilin    BZ-024  1072  3517
# SP/BZ-031  SP/BZ-031             Luboń (Luboń Wielki)    BZ-031  1022  3353
# SP/BZ-005  SP/BZ-005                          Turbacz    BZ-005  1315  4314
# SP/BZ-014  SP/BZ-014                        Mogielica    BZ-014  1171  3842
#
#           gridRef1 gridRef2 notes            validFrom              validTo  \
# SP/BI-003  22.5780  49.0988        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-070  20.2993  49.7708        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-082  20.3198  49.7467        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-001  19.5296  49.5732        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-059  19.8961  49.7689        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/WS-003  19.5536  50.4511        0001-01-01T00:00:00  0001-01-01T00:00:00
# OM/PO-040  21.2637  49.4473        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-010  20.2528  49.5653        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-030   20.376  49.6212        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-024  20.1916  49.6887        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-031  19.9919  49.6535        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-005  20.1113  49.5429        0001-01-01T00:00:00  0001-01-01T00:00:00
# SP/BZ-014  20.2768  49.6552        0001-01-01T00:00:00  0001-01-01T00:00:00
#
#            ... latitude locator points regionCode         regionName  \
# SP/BI-003  ...  49.0988  KN19gc     10         BI         Bieszczady
# SP/BZ-070  ...  49.7708  KN09ds      4         BZ  Beskidy Zachodnie
# SP/BZ-082  ...  49.7467  KN09dr      2         BZ  Beskidy Zachodnie
# SP/BZ-001  ...  49.5732  JN99sn     10         BZ  Beskidy Zachodnie
# SP/BZ-059  ...  49.7689  JN99ws      6         BZ  Beskidy Zachodnie
# SP/WS-003  ...  50.4511  JO90sk      1         WS      Wyzyna Slaska
# OM/PO-040  ...  49.4473  KN09pk      2         PO          Prešovský
# SP/BZ-010  ...  49.5653  KN09dn      8         BZ  Beskidy Zachodnie
# SP/BZ-030  ...  49.6212  KN09eo      8         BZ  Beskidy Zachodnie
# SP/BZ-024  ...  49.6887  KN09cq      8         BZ  Beskidy Zachodnie
# SP/BZ-031  ...  49.6535  JN99xp      8         BZ  Beskidy Zachodnie
# SP/BZ-005  ...  49.5429  KN09bn     10         BZ  Beskidy Zachodnie
# SP/BZ-014  ...  49.6552  KN09dp      8         BZ  Beskidy Zachodnie
#
#           associationCode associationName valid restrictionMask  \
# SP/BI-003              SP          Poland  True           False
# SP/BZ-070              SP          Poland  True           False
# SP/BZ-082              SP          Poland  True           False
# SP/BZ-001              SP          Poland  True           False
# SP/BZ-059              SP          Poland  True           False
# SP/WS-003              SP          Poland  True           False
# OM/PO-040              OM        Slovakia  True           False
# SP/BZ-010              SP          Poland  True           False
# SP/BZ-030              SP          Poland  True           False
# SP/BZ-024              SP          Poland  True           False
# SP/BZ-031              SP          Poland  True           False
# SP/BZ-005              SP          Poland  True           False
# SP/BZ-014              SP          Poland  True           False
#
#           restrictionList
# SP/BI-003              []
# SP/BZ-070              []
# SP/BZ-082              []
# SP/BZ-001              []
# SP/BZ-059              []
# SP/WS-003              []
# OM/PO-040              []
# SP/BZ-010              []
# SP/BZ-030              []
# SP/BZ-024              []
# SP/BZ-031              []
# SP/BZ-005              []
# SP/BZ-014              []
#
# [13 rows x 26 columns]

# %% [markdown]
# DataFrame now looks good for visualisation however we cannot use the data as they are not numeric:

# %%
df_summits_transposed.dtypes
# Out:
# summitCode         object
# name               object
# shortCode          object
# altM               object
# altFt              object
# gridRef1           object
# gridRef2           object
# notes              object
# validFrom          object
# validTo            object
# activationCount    object
# myActivations      object
# activationDate     object
# myChases           object
# activationCall     object
# longitude          object
# latitude           object
# locator            object
# points             object
# regionCode         object
# regionName         object
# associationCode    object
# associationName    object
# valid              object
# restrictionMask    object
# restrictionList    object
# dtype: object

# %% [markdown]
# Actually we need only four numbers for visualisation:
# - summit's reference: latitude and longitude,
# - numbers of chases for each summit,
# - summit's SOTA points value,
#
# so we can convert respective values:

# %%
df_summits_transposed['latitude'] = df_summits_transposed['latitude'].astype('float')
df_summits_transposed['longitude'] = df_summits_transposed['longitude'].astype('float')
df_summits_transposed['myChases'] = df_summits_transposed['myChases'].astype('int')
df_summits_transposed['points'] = df_summits_transposed['points'].astype('int')
df_summits_transposed.dtypes
# Out:
# summitCode          object
# name                object
# shortCode           object
# altM                object
# altFt               object
# gridRef1            object
# gridRef2            object
# notes               object
# validFrom           object
# validTo             object
# activationCount     object
# myActivations       object
# activationDate      object
# myChases             int32
# activationCall      object
# longitude          float64
# latitude           float64
# locator             object
# points               int32
# regionCode          object
# regionName          object
# associationCode     object
# associationName     object
# valid               object
# restrictionMask     object
# restrictionList     object
# dtype: object

# %% [markdown]
# Now we have everything we need regarding summits chased, but I think it's also good to include chaser's location on a map. Amateur radio operators use QTH locator grid (https://en.wikipedia.org/wiki/Maidenhead_Locator_System) and this data is available in ```MY_GRIDSQUARE``` field in the log.
#
# Grid locator in a form of two letters - two digits - two letters provides information about station's location with accuracy c.a. 5 km and may be calculated for geographical latitude and longituted. Here I'll use ```to_location``` function from ```maindenhead``` package to calculate coordinates and save it in the list.
#
# For every HAM there's one very personal place - home QTH. Based on the log entries, we can guess that it will be the most common grid locator (I know it's not always true, especially for operators usually operating from field). It will serves as a map center for us. If there is no chaser's QTH logged (which is possible), map will be centred on the most frequently chased summit.

# %%
## prepare list of chasing locations if any
my_coordinates = []

if ('MY_GRIDSQUARE' in df_log_SOTA) == True:

    for locator in df_log_SOTA['MY_GRIDSQUARE'].drop_duplicates():
            my_coordinates.append(list(mh.to_location(locator)))
    home_QTH = list(mh.to_location(df_log_SOTA['MY_GRIDSQUARE'].value_counts().idxmax()))
    map_center = home_QTH
else:
    map_center = [
        df_summits_transposed['latitude'][df_summits_transposed['myChases'].idxmax()],
        df_summits_transposed['longitude'][df_summits_transposed['myChases'].idxmax()]
    ]

# %% [markdown]
#  To make visualisation easier-to-read, I'll also standardise the count of QSO for each summit (so the value will be equal to 1 for most chased summit, and proportionally lower to remaining ones) and save it in newly created ```rel_Chases``` column.

# %%
df_summits_transposed['rel_Chases'] = df_summits_transposed['myChases']/df_summits_transposed['myChases'].max()
df_summits_transposed['rel_Chases']
# Out:
# SP/BI-003    0.0625
# SP/BZ-070    0.0625
# SP/BZ-082    0.0625
# SP/BZ-001    0.0625
# SP/BZ-059    0.0625
# SP/WS-003    0.0625
# OM/PO-040    0.0625
# SP/BZ-010    0.0625
# SP/BZ-030    1.0000
# SP/BZ-024    0.1250
# SP/BZ-031    0.1250
# SP/BZ-005    0.1250
# SP/BZ-014    0.1250
# Name: rel_Chases, dtype: float64

# %% [markdown]
# ### Data visualisation
#
# Now we can visualise chases avaiable in the log on a map with a support of Folium library. Before we start, I'll define a colormap to reflect summit's punctation. Based on a region and height, each summit is valued between 1 and 10 points. We'll use colormap where 1-points summits are marked with purple, 5-points ones - with orange, and 10-points ones - with red.

# %%
summit_points = cm.LinearColormap(colors=['purple', 'orange','red'], index=[1,5,10],vmin=1,vmax=10).to_step(10)

# %% [markdown]
# Let's draw a map centred on home QTH.

# %%
# prepare a map 
chasers_map = folium.Map(location=map_center, 
                         tiles="Stamen Terrain",
                        zoom_start=9)

# %% [markdown]
# Every summit chased is presented on a map with a circle centered at summit's coordinates. Circle's color represents it's points value, and diameter - how many chases were made with this particular summit.

# %%
# add summits to a map
for summit in df_log_summits['SOTA_REF']:
    folium.CircleMarker(
    location = [df_summits_transposed['latitude'][summit], df_summits_transposed['longitude'][summit]],
    radius = 20*df_summits_transposed['rel_Chases'][summit],
    popup = f"{df_summits_transposed['summitCode'][summit]},\n{df_summits_transposed['name'][summit]}\n{df_summits_transposed['myChases'][summit]} QSOs",
    color = summit_points(df_summits_transposed['points'][summit]),
    fill = True,
    weight = 0,
    fill_opacity = 1
).add_to(chasers_map)

# %% [markdown]
# Home QTH is presented with home marker.

# %%
# add home marker to map
if ('MY_GRIDSQUARE' in df_log_SOTA) == True:
    folium.Marker(
        location=home_QTH,
        popup=f"home QTH: {df_log_SOTA['MY_GRIDSQUARE'].value_counts().idxmax()}",
        icon=folium.Icon(color="blue", icon="glyphicon-home"),
    ).add_to(chasers_map)

# %% [markdown]
# ... and every other locator - with a blue dot.

# %%
# add your locations to map
for coordinate in my_coordinates:
    if coordinate == map_center:
        pass
    else:
        folium.CircleMarker(
            location = coordinate,
            popup = 'field QTH',
            color = 'dodgerblue',
            fill = True,
            fill_opacity = 1,
            weight = 0,
            radius = 5
        ).add_to(chasers_map)

# %% [markdown]
# Finally, we can add colormap bar into a map and print it.

# %%
chasers_map.add_child(summit_points)
# print map
display(chasers_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9b55c3176c6843b9875eebe6fca38712%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9b55c3176c6843b9875eebe6fca38712%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9b55c3176c6843b9875eebe6fca38712%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9b55c3176c6843b9875eebe6fca38712%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
